# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('./data/classified_pdfs_100k.csv')

grouped = df['classification'].value_counts().reset_index()
grouped.columns = ['classification', 'count']

# %%
# Create a pie chart
plt.figure(figsize=(10, 8))
plt.pie(grouped['count'], labels=grouped['classification'], autopct='%1.1f%%', startangle=90)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
plt.title('PDF Classification Distribution')
plt.savefig('./eda/pdf_classification_piechart.png')

# %%
df = pd.read_csv('./data/equally_distributed.csv')

# Group by classification and count
grouped = df['classification'].value_counts().reset_index()
grouped.columns = ['classification', 'count']

# %%
# Create a pie chart
plt.figure(figsize=(10, 8))
plt.pie(grouped['count'], labels=grouped['classification'], autopct='%1.1f%%', startangle=45)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
plt.title('PDF Classification Distribution')
plt.savefig('./eda/pdf_classification_piechart_equally_distributed.png')
